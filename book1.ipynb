# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\ADMIN\Desktop\my codes\my jupyter note book\dataset\winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
# looking at fixed acidity against quality to see a relationship
df_fixed_qual = df[['fixed acidity', 'quality']]
df_fixed_qual.head()
# Out:
#    fixed acidity  quality
# 0            7.4        5
# 1            7.8        5
# 2            7.8        5
# 3           11.2        6
# 4            7.4        5

# %%
plt.scatter(data=df_fixed_qual, x='fixed acidity', y='quality')
plt.title('Fixed-Acidity against quality')
plt.show()

# %%
try:
    plt.plot(data = df_fixed_qual, x='fixed acidity', y='quality')
    plt.title('Barplot of fixed acidity against quality')
except:
    print('This will not work')
# Out:
# This will not work

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#Trying alcohol and quality
df_al_qua = df[['alcohol', 'quality']]
df_al_qua_sorted = df_al_qua.sort_values(by='quality', ascending = False)
df_al_qua_sorted
#df_al_qua_sorted[df_al_qua_sorted['quality']>10]
# Out:
#       alcohol  quality
# 495      11.0        8
# 1403     10.0        8
# 390      12.9        8
# 1061     12.5        8
# 1202     11.7        8
# ...       ...      ...
# 690      10.7        3
# 1478     10.2        3
# 899      11.0        3
# 1299     10.9        3
# 832       9.9        3
#
# [1599 rows x 2 columns]

# %%
df_al_qua_sorted.value_counts()
# Out:
# alcohol  quality
# 9.50     5          97
# 9.40     5          79
# 9.20     5          50
# 9.80     5          49
# 9.30     5          44
#                     ..
# 10.75    6           1
# 10.70    7           1
#          3           1
# 10.55    7           1
# 14.90    5           1
# Name: count, Length: 190, dtype: int64

# %%
df_al_qua_sorted['alcohol'].mean()
# Out:
# 10.422983114446529

# %%
df_al_qua_sorted['alcohol'].unique()
# Out:
# array([11.        , 10.        , 12.9       , 12.5       , 11.7       ,
#        12.7       , 13.4       , 11.3       ,  9.8       , 11.4       ,
#        12.8       , 14.        , 12.6       , 13.1       , 11.8       ,
#        10.8       , 13.3       , 13.6       , 11.2       , 12.1       ,
#        11.5       , 10.2       , 10.5       , 11.1       , 10.6       ,
#        10.4       ,  9.9       , 10.9       , 12.        , 12.2       ,
#        11.9       , 12.4       , 12.3       ,  9.2       , 11.6       ,
#        13.        , 10.3       ,  9.7       , 10.7       ,  9.5       ,
#        10.1       , 10.55      , 13.56666667,  9.4       ,  9.1       ,
#         9.3       ,  9.        ,  9.6       , 13.2       ,  9.55      ,
#        11.06666667,  9.56666667, 10.03333333, 10.75      ,  9.23333333,
#         9.25      , 13.5       ,  8.7       ,  8.4       ,  8.8       ,
#        11.95      ,  8.5       , 14.9       ,  9.05      ,  9.95      ])

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#checking quantity against sulphates
df_sul_quan = df[['sulphates', 'quality']].sort_values(by='sulphates', ascending= False)
df_sul_quan
# Out:
#       sulphates  quality
# 151        2.00        4
# 92         1.98        5
# 91         1.95        6
# 86         1.95        6
# 723        1.62        5
# ...         ...      ...
# 65         0.39        5
# 1348       0.39        5
# 1369       0.37        4
# 1287       0.37        5
# 170        0.33        4
#
# [1599 rows x 2 columns]

# %%
plt.figure(figsize=(12, 4))
plt.hist(df_sul_quan['sulphates'], bins=20)
plt.show()

# %%
suf_count =df_sul_quan[df_sul_quan['quality']== 5]
suf_count
# Out:
#       sulphates  quality
# 92         1.98        5
# 723        1.62        5
# 169        1.59        5
# 13         1.56        5
# 1051       1.34        5
# ...         ...      ...
# 1347       0.39        5
# 64         0.39        5
# 65         0.39        5
# 1348       0.39        5
# 1287       0.37        5
#
# [681 rows x 2 columns]

# %%
#checking quality and ph
df_ph_qua = df[['quality','pH']].sort_values(by='quality', ascending=False)
df_ph_qua
# Out:
#       quality    pH
# 495         8  3.15
# 1403        8  3.23
# 390         8  3.56
# 1061        8  3.21
# 1202        8  3.35
# ...       ...   ...
# 690         3  3.63
# 1478        3  3.40
# 899         3  3.48
# 1299        3  3.50
# 832         3  3.38
#
# [1599 rows x 2 columns]

# %%
df[df_ph_qua['quality']>=7]
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12200\2585618592.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df_ph_qua['quality']>=7]
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 7               7.3              0.65         0.00             1.2      0.065
# 8               7.8              0.58         0.02             2.0      0.073
# 16              8.5              0.28         0.56             1.8      0.092
# 37              8.1              0.38         0.28             2.1      0.066
# 62              7.5              0.52         0.16             1.9      0.085
# ...             ...               ...          ...             ...        ...
# 1541            7.4              0.25         0.29             2.2      0.054
# 1544            8.4              0.37         0.43             2.3      0.063
# 1549            7.4              0.36         0.30             1.8      0.074
# ...

# %%
df[df_ph_qua['quality']<=4]
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12200\4102475725.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df_ph_qua['quality']<=4]
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 18              7.4             0.590         0.08             4.4      0.086
# 38              5.7             1.130         0.09             1.5      0.172
# 41              8.8             0.610         0.30             2.8      0.088
# 45              4.6             0.520         0.15             2.1      0.054
# 73              8.3             0.675         0.26             2.1      0.084
# ...             ...               ...          ...             ...        ...
# 1480            5.6             0.620         0.03             1.5      0.080
# 1482            7.2             0.580         0.54             2.1      0.114
# 1484            6.8             0.910         0.06             2.0      0.060
# ...

# %%
df[df_ph_qua['quality']==5].sort_values(by='residual sugar', ascending = False)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12200\3121681925.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df_ph_qua['quality']==5].sort_values(by='residual sugar', ascending = False)
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 480            10.6             0.280         0.39            15.5      0.069
# 1476            9.9             0.500         0.50            13.8      0.205
# 1474            9.9             0.500         0.50            13.8      0.205
# 1074            7.5             0.770         0.20             8.1      0.098
# 1071            7.5             0.770         0.20             8.1      0.098
# ...             ...               ...          ...             ...        ...
# 635             8.7             0.840         0.00             1.4      0.065
# 1376            8.2             0.885         0.20             1.4      0.086
# ...

# %%
df['total sulfur dioxide'].max()
# Out:
# 289.0

# %%
df_remarks = df

# %%
df_remarks['remarks'] = pd.cut(df_remarks['quality'], bins=[0,4,7, float('inf')], labels=['bad','good','best'])
df_remarks.sort_values(by = 'quality', ascending=False)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 495            10.7             0.350         0.53            2.60      0.070
# 1403            7.2             0.330         0.33            1.70      0.061
# 390             5.6             0.850         0.05            1.40      0.045
# 1061            9.1             0.400         0.50            1.80      0.071
# 1202            8.6             0.420         0.39            1.80      0.068
# ...             ...               ...          ...             ...        ...
# 690             7.4             1.185         0.00            4.25      0.097
# 1478            7.1             0.875         0.05            5.70      0.082
# 899             8.3             1.020         0.02            3.40      0.084
# 1299            7.6             1.580         0.00            2.10      0.137
# 832            10.4             0.440         0.42            1.50      0.145
#
# ...

# %%
(df_remarks['remarks']).value_counts()
# Out:
# remarks
# good    1518
# bad       63
# best      18
# Name: count, dtype: int64

# %%
plt.bar(height=2000, x='remarks', data=df_remarks)
plt.show()
